# %%
# %pylab inline
from wrappers import SparseGridWrapper
import numpy as np
import matplotlib
import seaborn as sns
from pysgpp import *
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
dim = 6
level = 3
l = 1E-8
grid = Grid.createLinearGrid(dim)
gridStorage = grid.getStorage()
gridGen = grid.createGridGenerator()
gridGen.regular(level)

size = 10
#x = np.random.rand(size*dim).reshape(size,-1)
#y = np.apply_along_axis(lambda p:4*p[0]*(1-p[0])*p[1]*(1-p[1]), 1, x)
#dataset = np.vstack([x.T,y]).T
 
f = SparseGridWrapper(grid, None, l)
x0 = np.ones(grid.getSize())
#     #algo = SGD(f, x0, callback=printy, learning_rate=0.2, loss_target=-np.inf)
#     algo = vSGDfd(f, x0, loss_target=-np.inf, init_samples=100)
#     algo.run(10000)


sns.set({'figure.figsize': (12, 12)})
H = f.currentDiagHess(x0)
sns.heatmap(H)
print "done"
# Out:
# done

# %%
matplotlib.pylab.imshow(H, interpolation='none', norm=matplotlib.colors.LogNorm())
print "done"
# Out:
# done
